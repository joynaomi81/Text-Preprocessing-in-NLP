# %% [markdown]
# <a href="https://colab.research.google.com/github/joynaomi81/Text-Preprocessing-in-NLP/blob/main/Text_Preprocessing_in_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Text Preprocessing in NLP Steps:
#
# * Import necessary library
# * Load data.
# * Data cleaning.
# * Text Preprocessing:
# * Lowercase
# * Removal of punctuations
# * Removal of stopwords
# * Removal of frequent words
# * Removal of rare words
# * Removal of special characters
# * Stemming
# * Lemmatization
# * Removal of URLs
# * Removal of HTML Tags
# * Spelling Correction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/text.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd.set_option('display.max_colwidth', None)
data = df[['comment_text']]

# %%
df.head() # Check for the first 5 rows
# Out:
#                                                                                                              comment_text  \
# 0                                This letter perfectly illustrates why any hoped for "reconciliation" is sheer stupidity.
# 1   One muslim casualty vs the hundreds and thousands of victims of muslim terrorism this year alone.  Darn islamophobia.
# 2                                                        (fuck you Osama bin laden and your afghanistani terrorist cunts)
# 3  As long as Trump keeps Stiggin' It to the libs, Palin-Americans won't care.\n\nHealthcare be damned! Full steam ahead!
# 4                                                             This article is a load of crap....  Another Fake News POLL!
#
#    toxic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df.tail() # Check for the last 5 rows
# Out:
#                                                                                                                                                                                                                                                                                                                         comment_text  \
# 19995                                                                                                                                                                                                                                                                                       i like smiley pancakes and crap on stick
# 19996                                                                                                                                                                                                 "\n\n""żem"" is not equal to ""że"".  ""żem"" is an older langage word and means ""że jestem"" in English means ""I am"".\n\n"
# 19997                                                                                    "\n\n Headlines \n\nCan you please add this comment to the Headlines on the main page, because I don't have access, since I am not an admin.  Thanks!\nThe 79th Academy Awards is held in the Kodak Theatre in Los Angeles, California.\n "
# 19998                                                                                                                                                                                                                                                                                                             Thank You, sorry.–
# 19999  Schooling \n\nI attended Harrison Trimble in Moncton, N.B and thats where Sidney earned a diploma from Harrison Trimble High School (Source: http://timestranscript.canadaeast.com/sports/article/698292\n\nI remember meeting him and seeing his photo on the Graduation Wall after.\n\nCan someone edit this to include it?
#
#        toxic
# 19995      0
# 19996      0
# 19997      0
# 19998      0
# 19999      0

# %%
# Check for the columns lables
df.columns
# Out:
# Index(['comment_text', 'toxic'], dtype='object')

# %%
df.info() # Information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   comment_text  20000 non-null  object
#  1   toxic         20000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 312.6+ KB

# %%
df.describe() # Descriptive statistics of the dataset
# Out:
#               toxic
# count  20000.000000
# mean       0.500000
# std        0.500013
# min        0.000000
# 25%        0.000000
# 50%        0.500000
# 75%        1.000000
# max        1.000000

# %%
df.shape # Check for the shape of the dataset
# Out:
# (20000, 2)

# %%
# Check for unique values
df.nunique()
# Out:
# comment_text    19960
# toxic               2
# dtype: int64

# %% [markdown]
# # Data cleaning

# %%
#check for missing values
df.isna().sum()
# Out:
# comment_text    0
# toxic           0
# dtype: int64

# %%
# Checking for duplicate rows in the DataFrame
df.duplicated().sum()
# Out:
# 39

# %% [markdown]
# There are 39 rows in the DataFrame that are duplicates of other rows.

# %%
# Drop duplicates rows
df = df.drop_duplicates()

# %%
# Check for the new data shape
df.shape
# Out:
# (19961, 2)

# %%
df.loc[:1] # locate a specific row
# Out:
#                                                                                                             comment_text  \
# 0                               This letter perfectly illustrates why any hoped for "reconciliation" is sheer stupidity.
# 1  One muslim casualty vs the hundreds and thousands of victims of muslim terrorism this year alone.  Darn islamophobia.
#
#    toxic
# 0      1
# 1      1

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ## Convert data to Lowercase

# %%
df.loc[:,'comment_text'] = df['comment_text'].str.lower()
df.head()
# Out:
#                                                                                                              comment_text  \
# 0                                this letter perfectly illustrates why any hoped for "reconciliation" is sheer stupidity.
# 1   one muslim casualty vs the hundreds and thousands of victims of muslim terrorism this year alone.  darn islamophobia.
# 2                                                        (fuck you osama bin laden and your afghanistani terrorist cunts)
# 3  as long as trump keeps stiggin' it to the libs, palin-americans won't care.\n\nhealthcare be damned! full steam ahead!
# 4                                                             this article is a load of crap....  another fake news poll!
#
#    toxic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ## Removal of Punctuations

# %%
def remove_punctuations(text):
  punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
  for x in text:
    if x in punctuations:
      text = text.replace(x, "")
  return text

# %%
df.loc[:,'comment_text'] = df['comment_text'].apply(remove_punctuations)
df.head()
# Out:
#                                                                                                           comment_text  \
# 0                                this letter perfectly illustrates why any hoped for reconciliation is sheer stupidity
# 1  one muslim casualty vs the hundreds and thousands of victims of muslim terrorism this year alone  darn islamophobia
# 2                                                       fuck you osama bin laden and your afghanistani terrorist cunts
# 3      as long as trump keeps stiggin it to the libs palinamericans wont care\n\nhealthcare be damned full steam ahead
# 4                                                               this article is a load of crap  another fake news poll
#
#    toxic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ## Removal of Stopwords

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('english'))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't"

# %%
words = set(stopwords.words('english'))
def remove_stopwords(text):
  return " ".join([word for word in str(text).split() if word not in words])

# %%
df.loc[:, 'comment_text'] = df['comment_text'].apply(lambda a: remove_stopwords(a))
df.head()
# Out:
#                                                                                       comment_text  \
# 0                                letter perfectly illustrates hoped reconciliation sheer stupidity
# 1  one muslim casualty vs hundreds thousands victims muslim terrorism year alone darn islamophobia
# 2                                                fuck osama bin laden afghanistani terrorist cunts
# 3        long trump keeps stiggin libs palinamericans wont care healthcare damned full steam ahead
# 4                                                         article load crap another fake news poll
#
#    toxic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ##  Removal of Frequent Words

# %%
from collections import Counter
word_count = Counter()
for text in df['comment_text'].values:
  for word in text.split():
    word_count[word] += 1

word_count.most_common(10)
# Out:
# [('article', 4083),
#  ('like', 3222),
#  ('page', 3115),
#  ('would', 2904),
#  ('one', 2866),
#  ('dont', 2775),
#  ('people', 2653),
#  ('==', 2536),
#  ('wikipedia', 2445),
#  ('fuck', 2249)]

# %%
FREQ_WORDS = set([w for (w, wc) in word_count.most_common(4)])
def remove_freqwords(text):
  return " ".join([word for word in str(text).split() if word not in FREQ_WORDS])

# %%
df['comment_text'] = df['comment_text'].apply(lambda a: remove_freqwords(a))
df.head()
# Out:
#                                                                                       comment_text  \
# 0                                letter perfectly illustrates hoped reconciliation sheer stupidity
# 1  one muslim casualty vs hundreds thousands victims muslim terrorism year alone darn islamophobia
# 2                                                fuck osama bin laden afghanistani terrorist cunts
# 3        long trump keeps stiggin libs palinamericans wont care healthcare damned full steam ahead
# 4                                                                 load crap another fake news poll
#
#    toxic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
RARE_WORDS = set([word for (word, wc) in word_count.most_common()[-20: -1]])
RARE_WORDS
# Out:
# {'110s10818',
#  '79th',
#  'cavalry',
#  'cio',
#  'growers',
#  'jestem',
#  'kodak',
#  'langage',
#  'moncton',
#  'pancakes',
#  'parmenion',
#  'persepolis',
#  'questioner',
#  'regrupped',
#  'rfx',
#  'sidney',
#  'sorry–',
#  'thessalian',
#  'xfd'}

# %%
def remove_rarewords(text):
  return " ".join([word for word in str(text).split() if word not in RARE_WORDS])

# %%
df['comment_text'] = df['comment_text'].apply(lambda a: remove_rarewords(a))
df.head()
# Out:
#                                                                                       comment_text  \
# 0                                letter perfectly illustrates hoped reconciliation sheer stupidity
# 1  one muslim casualty vs hundreds thousands victims muslim terrorism year alone darn islamophobia
# 2                                                fuck osama bin laden afghanistani terrorist cunts
# 3        long trump keeps stiggin libs palinamericans wont care healthcare damned full steam ahead
# 4                                                                 load crap another fake news poll
#
#    toxic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ## Removal of Special Characters

# %%
import re
def remove_spl_chars(text):
  text = re.sub('[^a-zA-Z0-9]', ' ', text)
  text = re.sub('\s+', ' ', text)
  return text

# %%
df['comment_text'] = df['comment_text'].apply(lambda a: remove_spl_chars(a))
df.head()
# Out:
#                                                                                       comment_text  \
# 0                                letter perfectly illustrates hoped reconciliation sheer stupidity
# 1  one muslim casualty vs hundreds thousands victims muslim terrorism year alone darn islamophobia
# 2                                                fuck osama bin laden afghanistani terrorist cunts
# 3        long trump keeps stiggin libs palinamericans wont care healthcare damned full steam ahead
# 4                                                                 load crap another fake news poll
#
#    toxic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ## Stemming

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
def stem_words(text):
  return " ".join([stemmer.stem(word) for word in text.split()])

# %%
df['comment_text'] = df['comment_text'].apply(lambda a: stem_words(a))
df.head()
# Out:
#                                                                              comment_text  \
# 0                                    letter perfectli illustr hope reconcili sheer stupid
# 1  one muslim casualti vs hundr thousand victim muslim terror year alon darn islamophobia
# 2                                        fuck osama bin laden afghanistani terrorist cunt
# 3     long trump keep stiggin lib palinamerican wont care healthcar damn full steam ahead
# 4                                                          load crap anoth fake news poll
#
#    toxic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ## Lemmatization

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
import nltk
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmetizer = WordNetLemmatizer()
nltk.download('wordnet')
wordnet_map = {"N": wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "AV": wordnet.ADV}

def lemmatize_words(text):
  pos_tagged_text = nltk.pos_tag(text.split())
  return " ".join([lemmetizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df['comment_text'] = df['comment_text'].apply(lambda a: lemmatize_words(a))
df.head()
# Out:
#                                                                             comment_text  \
# 0                                   letter perfectli illustr hope reconcili sheer stupid
# 1  one muslim casualti v hundr thousand victim muslim terror year alon darn islamophobia
# 2                                       fuck osama bin laden afghanistani terrorist cunt
# 3    long trump keep stiggin lib palinamerican wont care healthcar damn full steam ahead
# 4                                                         load crap anoth fake news poll
#
#    toxic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ## Removal of URLs

# %%
import re

def remove_urls(text):
  return re.sub(r'https?://\S+|www\.\S+', '', text) # remove urls

df['comment_text'] = df['comment_text'].apply(lambda a: remove_urls(a))
df.head()
# Out:
#                                                                             comment_text  \
# 0                                   letter perfectli illustr hope reconcili sheer stupid
# 1  one muslim casualti v hundr thousand victim muslim terror year alon darn islamophobia
# 2                                       fuck osama bin laden afghanistani terrorist cunt
# 3    long trump keep stiggin lib palinamerican wont care healthcar damn full steam ahead
# 4                                                         load crap anoth fake news poll
#
#    toxic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ## Removal of HTML Tags

# %%
def remove_html_tags(text):
  return re.sub(r'<.*?>', '', text)

df['comment_text'] = df['comment_text'].apply(lambda a: remove_html_tags(a))
df.head()
# Out:
#                                                                             comment_text  \
# 0                                   letter perfectli illustr hope reconcili sheer stupid
# 1  one muslim casualti v hundr thousand victim muslim terror year alon darn islamophobia
# 2                                       fuck osama bin laden afghanistani terrorist cunt
# 3    long trump keep stiggin lib palinamerican wont care healthcar damn full steam ahead
# 4                                                         load crap anoth fake news poll
#
#    toxic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ## Spelling Correction

# %%
# !pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.8.1-py3-none-any.whl.metadata (9.4 kB)
# Downloading pyspellchecker-0.8.1-py3-none-any.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 52.6 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.8.1

# %%
from spellchecker import SpellChecker
spell = SpellChecker()

def correct_spellings(text):
  corrected_text = []
  misspelled_words = spell.unknown(text.split())

# %%
df['spell_text'] = df['comment_text'].apply(lambda a: correct_spellings(a))
df.head()
# Out:
#                                                                             comment_text  \
# 0                                   letter perfectli illustr hope reconcili sheer stupid
# 1  one muslim casualti v hundr thousand victim muslim terror year alon darn islamophobia
# 2                                       fuck osama bin laden afghanistani terrorist cunt
# 3    long trump keep stiggin lib palinamerican wont care healthcar damn full steam ahead
# 4                                                         load crap anoth fake news poll
#
#    toxic spell_text
# 0      1       None
# 1      1       None
# 2      1       None
# 3      1       None
# 4      1       None
