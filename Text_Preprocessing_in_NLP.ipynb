# %% [markdown]
# <a href="https://colab.research.google.com/github/joynaomi81/Text-Preprocessing-in-NLP/blob/main/Text_Preprocessing_in_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/text.csv')

# %%
df.head() # Check for the first 5 rows
# Out:
#                                         comment_text  toxic
# 0  This letter perfectly illustrates why any hope...      1
# 1  One muslim casualty vs the hundreds and thousa...      1
# 2  (fuck you Osama bin laden and your afghanistan...      1
# 3  As long as Trump keeps Stiggin' It to the libs...      1
# 4  This article is a load of crap....  Another Fa...      1

# %%
df.tail() # Check for the last 5 rows
# Out:
#                                             comment_text  toxic
# 19995           i like smiley pancakes and crap on stick      0
# 19996  "\n\n""żem"" is not equal to ""że"".  ""żem"" ...      0
# 19997  "\n\n Headlines \n\nCan you please add this co...      0
# 19998                                 Thank You, sorry.–      0
# 19999  Schooling \n\nI attended Harrison Trimble in M...      0

# %%
# Check for the columns lables
df.columns
# Out:
# Index(['comment_text', 'toxic'], dtype='object')

# %%
df.info() # Information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   comment_text  20000 non-null  object
#  1   toxic         20000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 312.6+ KB

# %%
df.describe() # Descriptive statistics of the dataset
# Out:
#               toxic
# count  20000.000000
# mean       0.500000
# std        0.500013
# min        0.000000
# 25%        0.000000
# 50%        0.500000
# 75%        1.000000
# max        1.000000

# %%
df.shape # Check for the shape of the dataset
# Out:
# (20000, 2)

# %%
# Check for unique values
df.nunique()
# Out:
# comment_text    19960
# toxic               2
# dtype: int64

# %% [markdown]
# # Data cleaning

# %%
#check for missing values
df.isna().sum()
# Out:
# comment_text    0
# toxic           0
# dtype: int64

# %%
# Checking for duplicate rows in the DataFrame
df.duplicated().sum()
# Out:
# 39

# %% [markdown]
# There are 39 rows in the DataFrame that are duplicates of other rows.

# %%
# Drop duplicates rows
df = df.drop_duplicates()

# %%
# Check for the new data shape
df.shape
# Out:
# (19961, 2)

# %%
df.loc[:1] # locate a specific row
# Out:
#                                         comment_text  toxic
# 0  This letter perfectly illustrates why any hope...      1
# 1  One muslim casualty vs the hundreds and thousa...      1

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ## Convert data to Lowercase

# %%
df['clean_text'] = df['comment_text'].str.lower()
df.sample(5)
# Out:
#                                            comment_text  toxic  \
# 8693  Yeah but the beer they were hauling sucks........      1
# 8242  What the hell man!\nLook, I'm really pissed th...      1
# 3123  Shot in the leg?! He needs to resight that suc...      1
# 9219  Trumps sexual assaults are only irrelevant to ...      1
# 1138  I wish to thank the Marxist morons of Ontario ...      1
#
#                                              clean_text
# 8693  yeah but the beer they were hauling sucks........
# 8242  what the hell man!\nlook, i'm really pissed th...
# 3123  shot in the leg?! he needs to resight that suc...
# 9219  trumps sexual assaults are only irrelevant to ...
# 1138  i wish to thank the marxist morons of ontario ...

# %% [markdown]
# ## Removal of Punctuations

# %%
def remove_punctuations(text):
  punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
  for x in text:
    if x in punctuations:
      text = text.replace(x, "")
  return text

# %%
df['clean_text'] = df['clean_text'].apply(remove_punctuations)
df.head()
# Out:
#                                         comment_text  toxic  \
# 0  This letter perfectly illustrates why any hope...      1
# 1  One muslim casualty vs the hundreds and thousa...      1
# 2  (fuck you Osama bin laden and your afghanistan...      1
# 3  As long as Trump keeps Stiggin' It to the libs...      1
# 4  This article is a load of crap....  Another Fa...      1
#
#                                           clean_text
# 0  this letter perfectly illustrates why any hope...
# 1  one muslim casualty vs the hundreds and thousa...
# 2  fuck you osama bin laden and your afghanistani...
# 3  as long as trump keeps stiggin it to the libs ...
# 4  this article is a load of crap  another fake n...

# %% [markdown]
# ## Removal of Stopwords

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('english'))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't"

# %%
words = set(stopwords.words('english'))
def remove_stopwords(text):
  return " ".join([word for word in str(text).split() if word not in words])

# %%
df['clean_text'] = df['clean_text'].apply(lambda a: remove_stopwords(a))
df.head()
# Out:
#                                         comment_text  toxic  \
# 0  This letter perfectly illustrates why any hope...      1
# 1  One muslim casualty vs the hundreds and thousa...      1
# 2  (fuck you Osama bin laden and your afghanistan...      1
# 3  As long as Trump keeps Stiggin' It to the libs...      1
# 4  This article is a load of crap....  Another Fa...      1
#
#                                           clean_text
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4           article load crap another fake news poll

# %% [markdown]
# ##  Removal of Frequent Words

# %%
from collections import Counter
word_count = Counter()
for text in df['clean_text'].values:
  for word in text.split():
    word_count[word] += 1

word_count.most_common(10)
# Out:
# [('article', 4083),
#  ('like', 3222),
#  ('page', 3115),
#  ('would', 2904),
#  ('one', 2866),
#  ('dont', 2775),
#  ('people', 2653),
#  ('==', 2536),
#  ('wikipedia', 2445),
#  ('fuck', 2249)]

# %%
FREQ_WORDS = set([w for (w, wc) in word_count.most_common(4)])
def remove_freqwords(text):
  return " ".join([word for word in str(text).split() if word not in FREQ_WORDS])

# %%
df['clean_text'] = df['clean_text'].apply(lambda a: remove_freqwords(a))
df.head()
# Out:
#                                         comment_text  toxic  \
# 0  This letter perfectly illustrates why any hope...      1
# 1  One muslim casualty vs the hundreds and thousa...      1
# 2  (fuck you Osama bin laden and your afghanistan...      1
# 3  As long as Trump keeps Stiggin' It to the libs...      1
# 4  This article is a load of crap....  Another Fa...      1
#
#                                           clean_text
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll

# %%
RARE_WORDS = set([word for (word, wc) in word_count.most_common()[-20: -1]])
RARE_WORDS
# Out:
# {'110s10818',
#  '79th',
#  'cavalry',
#  'cio',
#  'growers',
#  'jestem',
#  'kodak',
#  'langage',
#  'moncton',
#  'pancakes',
#  'parmenion',
#  'persepolis',
#  'questioner',
#  'regrupped',
#  'rfx',
#  'sidney',
#  'sorry–',
#  'thessalian',
#  'xfd'}

# %%
def remove_rarewords(text):
  return " ".join([word for word in str(text).split() if word not in RARE_WORDS])

# %%
df['clean_text'] = df['clean_text'].apply(lambda a: remove_rarewords(a))
df.head()
# Out:
#                                         comment_text  toxic  \
# 0  This letter perfectly illustrates why any hope...      1
# 1  One muslim casualty vs the hundreds and thousa...      1
# 2  (fuck you Osama bin laden and your afghanistan...      1
# 3  As long as Trump keeps Stiggin' It to the libs...      1
# 4  This article is a load of crap....  Another Fa...      1
#
#                                           clean_text
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll

# %% [markdown]
# ## Removal of Special Characters

# %%
import re
def remove_spl_chars(text):
  text = re.sub('[^a-zA-Z0-9]', ' ', text)
  text = re.sub('\s+', ' ', text)
  return text

# %%
df['clean_text'] = df['clean_text'].apply(lambda a: remove_spl_chars(a))
df.head()
# Out:
#                                         comment_text  toxic  \
# 0  This letter perfectly illustrates why any hope...      1
# 1  One muslim casualty vs the hundreds and thousa...      1
# 2  (fuck you Osama bin laden and your afghanistan...      1
# 3  As long as Trump keeps Stiggin' It to the libs...      1
# 4  This article is a load of crap....  Another Fa...      1
#
#                                           clean_text
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll

# %% [markdown]
# ## Stemming

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
def stem_words(text):
  return " ".join([stemmer.stem(word) for word in text.split()])

# %%
df['stemmed_text'] = df['clean_text'].apply(lambda a: stem_words(a))
df.head()
# Out:
#                                         comment_text  toxic  \
# 0  This letter perfectly illustrates why any hope...      1
# 1  One muslim casualty vs the hundreds and thousa...      1
# 2  (fuck you Osama bin laden and your afghanistan...      1
# 3  As long as Trump keeps Stiggin' It to the libs...      1
# 4  This article is a load of crap....  Another Fa...      1
#
#                                           clean_text  \
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll
#
#                                         stemmed_text
# 0  letter perfectli illustr hope reconcili sheer ...
# 1  one muslim casualti vs hundr thousand victim m...
# 2   fuck osama bin laden afghanistani terrorist cunt
# 3  long trump keep stiggin lib palinamerican wont...
# 4                     load crap anoth fake news poll

# %% [markdown]
# ## Lemmatization

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
import nltk
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmetizer = WordNetLemmatizer()
nltk.download('wordnet')
wordnet_map = {"N": wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "AV": wordnet.ADV}

def lemmatize_words(text):
  pos_tagged_text = nltk.pos_tag(text.split())
  return " ".join([lemmetizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df['lemmatized_text'] = df['clean_text'].apply(lambda a: lemmatize_words(a))
df.head()
# Out:
#                                         comment_text  toxic  \
# 0  This letter perfectly illustrates why any hope...      1
# 1  One muslim casualty vs the hundreds and thousa...      1
# 2  (fuck you Osama bin laden and your afghanistan...      1
# 3  As long as Trump keeps Stiggin' It to the libs...      1
# 4  This article is a load of crap....  Another Fa...      1
#
#                                           clean_text  \
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll
#
#                                         stemmed_text  \
# 0  letter perfectli illustr hope reconcili sheer ...
# 1  one muslim casualti vs hundr thousand victim m...
# 2   fuck osama bin laden afghanistani terrorist cunt
# 3  long trump keep stiggin lib palinamerican wont...
# 4                     load crap anoth fake news poll
#
#                                      lemmatized_text
# 0  letter perfectly illustrate hoped reconciliati...
# 1  one muslim casualty v hundred thousand victim ...
# 2   fuck osama bin laden afghanistani terrorist cunt
# 3  long trump keep stiggin libs palinamericans wo...
# 4                   load crap another fake news poll

# %% [markdown]
# ## Removal of URLs

# %%
import re

def remove_urls(text):
  return re.sub(r'https?://\S+|www\.\S+', '', text) # remove urls

df['url_text'] = df['clean_text'].apply(lambda a: remove_urls(a))
df.head()
# Out:
#                                         comment_text  toxic  \
# 0  This letter perfectly illustrates why any hope...      1
# 1  One muslim casualty vs the hundreds and thousa...      1
# 2  (fuck you Osama bin laden and your afghanistan...      1
# 3  As long as Trump keeps Stiggin' It to the libs...      1
# 4  This article is a load of crap....  Another Fa...      1
#
#                                           clean_text  \
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll
#
#                                         stemmed_text  \
# 0  letter perfectli illustr hope reconcili sheer ...
# 1  one muslim casualti vs hundr thousand victim m...
# 2   fuck osama bin laden afghanistani terrorist cunt
# 3  long trump keep stiggin lib palinamerican wont...
# 4                     load crap anoth fake news poll
#
#                                      lemmatized_text  \
# 0  letter perfectly illustrate hoped reconciliati...
# 1  one muslim casualty v hundred thousand victim ...
# 2   fuck osama bin laden afghanistani terrorist cunt
# 3  long trump keep stiggin libs palinamericans wo...
# 4                   load crap another fake news poll
#
#                                             url_text  \
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll
#
#                                            html_text
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll

# %% [markdown]
# ## Removal of HTML Tags

# %%
def remove_html_tags(text):
  return re.sub(r'<.*?>', '', text)

df['html_text'] = df['clean_text'].apply(lambda a: remove_html_tags(a))
df.head()
# Out:
#                                         comment_text  toxic  \
# 0  This letter perfectly illustrates why any hope...      1
# 1  One muslim casualty vs the hundreds and thousa...      1
# 2  (fuck you Osama bin laden and your afghanistan...      1
# 3  As long as Trump keeps Stiggin' It to the libs...      1
# 4  This article is a load of crap....  Another Fa...      1
#
#                                           clean_text  \
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll
#
#                                         stemmed_text  \
# 0  letter perfectli illustr hope reconcili sheer ...
# 1  one muslim casualti vs hundr thousand victim m...
# 2   fuck osama bin laden afghanistani terrorist cunt
# 3  long trump keep stiggin lib palinamerican wont...
# 4                     load crap anoth fake news poll
#
#                                      lemmatized_text  \
# 0  letter perfectly illustrate hoped reconciliati...
# 1  one muslim casualty v hundred thousand victim ...
# 2   fuck osama bin laden afghanistani terrorist cunt
# 3  long trump keep stiggin libs palinamericans wo...
# 4                   load crap another fake news poll
#
#                                             url_text  \
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll
#
#                                            html_text
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll

# %% [markdown]
# ## Spelling Correction

# %%
# !pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.8.1-py3-none-any.whl.metadata (9.4 kB)
# Downloading pyspellchecker-0.8.1-py3-none-any.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 61.4 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.8.1

# %%
from spellchecker import SpellChecker
spell = SpellChecker()

def correct_spellings(text):
  corrected_text = []
  misspelled_words = spell.unknown(text.split())

# %%
df['spell_text'] = df['clean_text'].apply(lambda a: correct_spellings(a))
df.head()
# Out:
#                                         comment_text  toxic  \
# 0  This letter perfectly illustrates why any hope...      1
# 1  One muslim casualty vs the hundreds and thousa...      1
# 2  (fuck you Osama bin laden and your afghanistan...      1
# 3  As long as Trump keeps Stiggin' It to the libs...      1
# 4  This article is a load of crap....  Another Fa...      1
#
#                                           clean_text  \
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll
#
#                                         stemmed_text  \
# 0  letter perfectli illustr hope reconcili sheer ...
# 1  one muslim casualti vs hundr thousand victim m...
# 2   fuck osama bin laden afghanistani terrorist cunt
# 3  long trump keep stiggin lib palinamerican wont...
# 4                     load crap anoth fake news poll
#
#                                      lemmatized_text  \
# 0  letter perfectly illustrate hoped reconciliati...
# 1  one muslim casualty v hundred thousand victim ...
# 2   fuck osama bin laden afghanistani terrorist cunt
# 3  long trump keep stiggin libs palinamericans wo...
# 4                   load crap another fake news poll
#
#                                             url_text  \
# 0  letter perfectly illustrates hoped reconciliat...
# 1  one muslim casualty vs hundreds thousands vict...
# 2  fuck osama bin laden afghanistani terrorist cunts
# 3  long trump keeps stiggin libs palinamericans w...
# 4                   load crap another fake news poll
#
#                                            html_text spell_text
# 0  letter perfectly illustrates hoped reconciliat...       None
# 1  one muslim casualty vs hundreds thousands vict...       None
# 2  fuck osama bin laden afghanistani terrorist cunts       None
# 3  long trump keeps stiggin libs palinamericans w...       None
# 4                   load crap another fake news poll       None
